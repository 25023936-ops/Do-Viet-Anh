# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input())
a = n*2
print(a)
# Out:
# 8

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khuvui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
a = float(input())
b = float(input())
HCN = (a*b)
r = a/2
circle = r*r*3.14
Other= HCN - circle
print(f"{Other:.2f}")
# Out:
# 2.86

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = str(input())
tmp = ord(c)
if (tmp>=97 and tmp<=122):
    ans = chr(ord(c)-32)
else:
    ans = chr(ord(c)+32)
print(ans)
# Out:
# D

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = str(input())
tmp = ord(c)
if (tmp>=97 and tmp<=122 or tmp>=65 and tmp<=90):
    print(c, "là kí tự alphabet")
else:
    print(c, "không phải là kí tự alphabet")
# Out:
# 1 không phải là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
a = str(input())
if (a=='A'):
    Result = "z"
else:
    Result = chr(ord(a)+31)
print(Result)
# Out:
# 

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c = map(float,input().split())
def Kiem_tra(a,b,c):
    if (a+b>c and b+c>a and c+a>b):
        return True
    else:
        return False  
if (Kiem_tra(a,b,c)==False):
    print("Khong phai 3 canh tam giác")
else:
    p = (a+b+c)/2
    ans = (p*(p-a)*(p-b)*(p-c))**0.5
    print(f"{ans:.(k)}f")
# Out:
# Khong phai 3 canh tam giác

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này

# %%
s = str(input())
print(s[4],s[8])
# Out:
# 2 9

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:
# Từ 0 – 50kWh: 1.984 đồng/kWh
# Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
print("Ten chu ho: ")
name = str(input())
print("Chi so thang truoc:")
a = int(input())
print("Chi so thang nay:")
b = int(input())
st = b - a
if (st<=50):
    ans = st*1984
elif (st>50 and st<=100):
    ans = (st%50)*2050 + 50*1984
elif (st>100 and st<=200):
    ans = (st%50)*2380 + 50*(1984*2050)
elif (st>200 and st<=300):
    ans = (st%100)*2998 + 50*(1984*2050) + 100*2380
elif (st>300 and st<=400):
    ans = (st%100)*3350 + 50*(1984*2050) + 100*(2380+2998)
elif (st>400):
    ans = (st-400)*3460 + 50*(1984*2050) + 100*(2380+2998+3350)
ans = int(ans*108/100)
print("Ho va ten: ", name)
print("Tien phai tra là: ",ans)
# Out:
# Ten chu ho:
# Chi so thang truoc:
# Chi so thang nay:
# Ho va ten:  12
# Tien phai tra là:  220538862

# %% [markdown]
# Một số bài tập khác:

# %% [markdown]
# 1. Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó là số chẵn hay số lẻ.

# %%
Number= int(input())
if Number%2==0:
    print(f"{Number} la so chan")
else:
    print(f"{Number} la so le")
# Out:
# 3 la so le

# %% [markdown]
# 2. Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
check = n%10
if check==5:
    print ("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# 3. Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
if n%3 == 0 and n%5 == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# 4. Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
Birthyear= int(input())
if Birthyear <= 2007:
    print("Du DK")
else:
    print("Ko du DK")
# Out:
# Ko du DK

# %% [markdown]
# 5. So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau.

# %%
a, b = map(int,input().split())
if a > b:
    print(f"{a} la lon nhat")
elif a==b:
    print(f"{a} va {b} bang nhau")
else:
    print(f"{b} la so lon nhat")
# Out:
# 3 la so lon nhat

# %% [markdown]
# W6A16 Nhập vào mảng n hàng, m cột số nguyên. In lại mảng ra màn hình như ma ̣ trận hai chiều, định dạng mỗi phần tử 4 vị trí căn phải

# %%
a, b = map(int, input().split())
c = [list(map(int, input().split())) for _ in range(a)]
for ha in c:
    for x in ha:
        print(f"{x:4d}", end="")
    print()
# Out:
#    1   3   2   4   5   2

# %% [markdown]
# W6A17 Nhập vào mảng vuông 2 chiều n hàng, n cột, in ra đường chéo chính và đường chéo

# %%
a = int(input())
c = [list(map(int, input().split())) for _ in range(a)]
cheo_chinh = [c[i][i] for i in range(a)]
cheo_phu = [c[i][a - 1 - i] for i in range(a)]
print("Đường chéo chính:", *cheo_chinh)
print("Đường chéo phụ:", *cheo_phu)

# %% [markdown]
# W6A18 Nhap vào mảng n hàng, m cột số nguyên và số nguyên k (n, m, k nhập trên ̣ cùng một dòng, cách nhau dấu cách). Tính và in ra tổng các phần tử trên cột k (hàng k)

# %%
a, b, k = map(int, input().split())
c = [list(map(int, input().split())) for _ in range(a)]
tong_hang_k = sum(c[k])
tong_cot_k = sum(row[k] for row in c)
print(f"Tổng hàng {k}: {tong_hang_k}")
print(f"Tổng cột {k}: {tong_cot_k}")

# %% [markdown]
# W6A19 Viết hàm đưa vào 1 list số nguyên, tìm và trả về vị trí có giá trị lớn nhất trong list

# %%
a=list(map(int, input().split()))
max=a[0]
for i in a:
    if i>max:
        max=i
print(max)

# %% [markdown]
# W6A20 Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử đầu tiên có giá trị k trong list, nếu không có thì trả về -1

# %%
def timk(a,k):
    for i in range(len(a)):
        if a[i]==k:
            return i
    return -1
a=list(map(int, input().split()))
b=int(input())
timk(a,b)

# %% [markdown]
# W6A21 Nhập một dòng gồm các chuỗi (tách bởi dấu cách). Tạo dictionary ánh xạ chuỗi -> tuple các vị trí (0-based) mà chuỗi đó xuất hiện

# %%
a=input().split()
b=len(a)
c={}
for i in range(b):
    if a[i] not in c:
        c[a[i]]=i
    else:
        c[a[i]].append(i)
d={key : tuple(value) for key, value in c.items()}
print(d)

# %% [markdown]
# W6A22 Viết hàm đưa vào 1 list số nguyên, tìm và trả về vị trí có giá trị lớn nhất trong list

# %%
a=list(map(int, input().split()))
max=a[0]
for i in range(1, len(a)):
    if a[i] > max:
        max = a[i]
        vitri = i
print(max, vitri)

# %% [markdown]
# W6A23 VIết hàm xóa đi các số <x có trong mảng

# %%
a=list(map(int, input().split()))
x=int(input())
a=[i for i in a if i>x]
print(a)

# %% [markdown]
# W6A24 Viêết hàm đẩy tất cả các số 0 về đầu (về cuối), các số khác vẫn đúng vị trí trước sau: 0 2 3 2 4 0 0 0 9 => 0 0 0 2 3 2 4 9

# %%
a=list(map(int, input().split()))
b=[]
c=[]
for i in a:
    if i==0:
        b.append(i)
    else:        
        c.append(i)
d=b+c
print(d)

# %% [markdown]
# W6A25 Cho dãy chỉ gồm N giá trị từ 0 - 9 . Kiểm tra xem giá trị nào không có trong mảng

# %%
a=list(map(int, input().split()))
b=[ i for i in range(10) if i not in a]
print(b)

# %% [markdown]
# W6A26 Tính tổng các phần tử cực đại địa phương trong một danh sách, không tính 2 số đầu,cuối.

# %%
a = list(map(int, input().split()))
b = 0
for i in range(1, len(a) - 1):
    if a[i] > a[i-1] and a[i] > a[i+1]:
        b += a[i]
print(b)

# %% [markdown]
# W6A27 Cho một dãy số nguyên, Tìm và in ra vị trí các số < x (x là giá trị cho trước).

# %%
a = list(map(int, input().split()))
x = int(input())
c = [i for i in range(len(a)) if a[i] < x]
print(*c)

# %% [markdown]
# W6A28 Cho một dãy các số nguyên, kiểm tra xem nó là dãy tăng thực sự hay giảm thực sự, hay vô danh (không tăng, không giảm)

# %%
a = list(map(int, input().split()))
b = sorted(list(set(a)))
c = b[::-1]
if a == b and len(set(a)) == len(a):
    print("Tăng thực sự")
elif a == c and len(set(a)) == len(a):
    print("Giảm thực sự")
else:
    print("Vô danh")
